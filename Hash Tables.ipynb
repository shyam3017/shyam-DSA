# %%
# Hash Tables, Hash maps, Dictionaries...
# Hash Tables
# insert --> O(1)
# lookup --> O(1)
# delete --> O(1)
# search --> O(1)
def fun():
    print('ahhhh!')
    
user = {
    'age' : 21,
    'name' : 'sade',
    'magic' : True,
    'scream' : fun()
}

user['age'] # O(1)
user['spell'] = 'abra kadabra' #O(1)
# Out:
# ahhhh!
# {'age': 21, 'name': 'sade', 'magic': True, 'scream': None}

# %%
# cons os hash tables
# When there is a collision the time complexity of lookup would increased to O(n/k)
# sometimes it might increased to O(n)

# %%
# Hash tables or has maps in Python are implemented through the built-in dictionary data type. The keys of a dictionary in Python are generated by a hashing function. The elements of a dictionary are not ordered and they can be changed.
# Dictionaries can be created in two ways:

# Using curly braces ({})
# Using the dict() function

# %%
# Implementation of Hash Table
class HashTable:
    def __init__(self, capacity):
        self.capacity = capacity
        self.data = [None] * capacity
    
    def _hash(self, key):
        return hash(key) % self.capacity
        
    def insert(self, key, value):
        address = self._hash(key)
        if not self.data[address]:
            self.data[address] = []
        self.data[address].append([key, value])
        return self.data
    
    def get(self, key):
        address = self._hash(key)
        currentBucket = self.data[address]
        if currentBucket:
            for i in range(0, len(currentBucket)):
                if currentBucket[i][0] == key:
                    return currentBucket[i][1]
        return None
    
myHashTable = HashTable(50)
myHashTable.insert('grapes', 100)
myHashTable.insert('apples', 101)
myHashTable.insert('guva', 102)
myHashTable.get('guva')
# Out:
# 102

# %%
# Using dictionary in python
# building a dictionary
myDict = dict([('sade', 90), ('man', 21)])
for key, value in myDict.items():
    print(key, value)
print(myDict)
# Out:
# sade 90
# man 21
# {'sade': 90, 'man': 21}

# %%
myDict_2 = dict(hello=5, hi=2, man=3)
myDict_2
# Out:
# {'hello': 5, 'hi': 2, 'man': 3}

# %%
myDict_3 = {'this' : 4,
           'is' : 2,
           'dictionary' : 10}
myDict_3
# Out:
# {'this': 4, 'is': 2, 'dictionary': 10}

# %%
myDict_2['hi'] = 4
myDict_2
# Out:
# {'hello': 5, 'hi': 4, 'man': 3}

# %%
del myDict['man']
myDict
# Out:
# {'sade': 90}

# %%
myDict['ham'] = 3
myDict
# Out:
# {'sade': 90, 'ham': 3}

# %%
"sade" in myDict
# Out:
# True

# %%
'sade' not in myDict
# Out:
# False

# %%
# Looping techniques
football = {'Ronaldo' : 7,
           'Messi' : 10,
           'neymar' : 11}
for k, v in football.items():
    print(k, v)
# Out:
# Ronaldo 7
# Messi 10
# neymar 11

# %%
# Time complexity of hash tables
# Insert --> O(1)
# Delete --> O(1)
# Search --> O(1)
# Space complexity
# Space --> O(n)

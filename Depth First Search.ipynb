# %%
# BST constructor

class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

class BST:
    def __init__(self):
        self.root = None
        
    def insert(self, value):
        new_node = Node(value)
        if self.root is None:
            self.root = new_node
            return True
        
        temp = self.root
        
        while True:
            if new_node.value == temp.value:
                return False
            if new_node.value < temp.value:
                if temp.left is None:
                    temp.left = new_node
                    return True
                temp = temp.left
            else:
                if temp.right is None:
                    temp.right = new_node
                    return True
                temp = temp.right
                
    def lookup(self, value):
        temp = self.root
        
        while temp is not None:
            if value < temp.value:
                temp = temp.left
            elif value > temp.value:
                temp = temp.right
            else:
                return True
        
        return False
    
    def BFS(self, root):
        current_node = self.root
        my_list = []
        myqueue = []
        myqueue.append(current_node)
        
        while len(myqueue) > 0:
            current_node = myqueue.pop(0)
            my_list.append(current_node.value)
            
            if current_node.left:
                myqueue.append(current_node.left)
            if current_node.right:
                myqueue.append(current_node.right)
        
        return my_list
    
    def BFSR(self, queue, rlist):
        if len(queue) == 0:
            return rlist
        current_node = queue.pop(0)
        rlist.append(current_node.value)

        if current_node.left:
            queue.append(current_node.left)
        if current_node.right:
            queue.append(current_node.right)
            
        return self.BFSR(queue, rlist)
    
    def DFSInorder(self, root):
        height = 0
        def inorder(node, lisy):
            if node.left:
                inorder(node.left, lisy)
            lisy.append(node.value)
            height += 1
            if node.right:
                inorder(node.right, lisy)
            return lisy, height
        return inorder(self.root, [])

    def DFSpreorder(self, root):
        def preorder(node, lisy):
            lisy.append(node.value)
            if node.left:
                preorder(node.left, lisy)
            if node.right:
                preorder(node.right, lisy)
            return lisy
        return preorder(self.root, [])

    def DFSpostorder(self, root):
        def postorder(node, lisy):
            if node.left:
                postorder(node.left, lisy)
            if node.right:
                postorder(node.right, lisy)
            lisy.append(node.value)
            return lisy
        return postorder(self.root, [])

# %%
my_tree = BST()
my_tree.insert(9)
my_tree.insert(4)
my_tree.insert(20)
my_tree.insert(1)
my_tree.insert(6)
my_tree.insert(15)
my_tree.insert(170)

print(my_tree.lookup(99))
print(my_tree.root.value)
print(my_tree.root.left.value)
print(my_tree.root.right.value)
print(my_tree.BFS(my_tree.root))
print(my_tree.BFSR([my_tree.root], []))
print(my_tree.DFSInorder(my_tree.root))
print(my_tree.DFSpreorder(my_tree.root))
print(my_tree.DFSpostorder(my_tree.root))
# Out:
# False
# 9
# 4
# 20
# [9, 4, 20, 1, 6, 15, 170]
# [9, 4, 20, 1, 6, 15, 170]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[6], line 16
#      14 print(my_tree.BFS(my_tree.root))
#      15 print(my_tree.BFSR([my_tree.root], []))
# ---> 16 print(my_tree.DFSInorder(my_tree.root))
#      17 print(my_tree.DFSpreorder(my_tree.root))
#      18 print(my_tree.DFSpostorder(my_tree.root))
#
# Cell In[5], line 88, in BST.DFSInorder(self, root)
#      86         inorder(node.right, lisy)
#      87     return lisy, height
# ---> 88 return inorder(self.root, [])
#
# Cell In[5], line 82, in BST.DFSInorder.<locals>.inorder(node, lisy)
#      80 def inorder(node, lisy):
#      81     if node.left:
# ---> 82         inorder(node.left, lisy)
#      83     lisy.append(node.value)
#      84     height += 1
#
# Cell In[5], line 82, in BST.DFSInorder.<locals>.inorder(node, lisy)
# ...
